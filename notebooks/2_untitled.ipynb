# %%
import pandas as pd
import numpy as np

# %%
recipes = pd.read_csv('../data_exports/recipes_csv').replace('NaN', np.nan).drop(['Unnamed: 0'], axis=1)
recipes
# Out:
#                                                      URL  \
# 0      https://www.recetasgratis.net/receta-de-torrej...
# 1      https://www.recetasgratis.net/receta-de-arroz-...
# 2      https://www.recetasgratis.net/receta-de-pastel...
# 3      https://www.recetasgratis.net/receta-de-risott...
# 4      https://www.recetasgratis.net/receta-de-arroz-...
# ...                                                  ...
# 10754  https://www.recetasgratis.net/receta-de-rollo-...
# 10755  https://www.recetasgratis.net/receta-de-palta-...
# 10756  https://www.recetasgratis.net/receta-de-alcach...
# 10757  https://www.recetasgratis.net/receta-de-aguaca...
# 10758  https://www.recetasgratis.net/receta-de-aguaca...
#
#                                            Nombre           Categoria  \
# 0                               Torrejas de arroz  Arroces y cereales
# 1                      Arroz con bacalao y gambas  Arroces y cereales
# ...

# %%
recipes.isna().sum()
# Out:
# URL                   0
# Nombre                0
# Categoria             0
# Comensales         4841
# Tiempo             4481
# Tipo               5008
# Dificultad         3690
# Caracteristicas    4032
# Ingredientes         20
# dtype: int64

# %%
samp = recipes.loc[np.random.choice(recipes[recipes.Categoria == 'Carne'].index.values, 1)]
samp_cell = [samp.iloc[0,0], samp.iloc[0,1]]
samp_cell
# Out:
# ['https://www.recetasgratis.net/receta-de-solomillo-de-cerdo-en-salsa-de-almendras-61258.html',
#  'Solomillo de cerdo en salsa de almendras']

# %%
seledict = {'Comida' : [samp_cell,
                        samp_cell,
                        samp_cell,
                        samp_cell,
                        samp_cell,
                        samp_cell,
                        samp_cell,
                       ],
            'Cena': [samp_cell,
                     samp_cell,
                     samp_cell,
                     samp_cell,
                     samp_cell,
                     samp_cell,
                     samp_cell] 
            }



plan = pd.DataFrame.from_dict(seledict, orient='index', columns=['Lunes','Martes','Miercoles','Jueves','Viernes','Sabado','Domingo'])

plan
# Out:
#                                                     Lunes  \
# Comida  [https://www.recetasgratis.net/receta-de-solom...
# Cena    [https://www.recetasgratis.net/receta-de-solom...
#
#                                                    Martes  \
# Comida  [https://www.recetasgratis.net/receta-de-solom...
# Cena    [https://www.recetasgratis.net/receta-de-solom...
#
#                                                 Miercoles  \
# Comida  [https://www.recetasgratis.net/receta-de-solom...
# Cena    [https://www.recetasgratis.net/receta-de-solom...
#
#                                                    Jueves  \
# Comida  [https://www.recetasgratis.net/receta-de-solom...
# Cena    [https://www.recetasgratis.net/receta-de-solom...
#
#                                                   Viernes  \
# Comida  [https://www.recetasgratis.net/receta-de-solom...
# Cena    [https://www.recetasgratis.net/receta-de-solom...
#
#                                                    Sabado  \
# ...
